# %%
from mixup_generator import *
# Out:
# /Users/arunpatala/thenv/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /Users/arunpatala/thenv/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import keras
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
num_classes = 10
generator1 = MixTensorGenerator(np.expand_dims(x_train,-1), y_train, alpha=1.0, num_classes=num_classes)()

# %%
np.expand_dims(x_train,-1).shape
# Out:
# (60000, 28, 28, 1)

# %%
x, y = next(generator1)
cols, rows = 5, 4
img_num = cols * rows

for i in range(img_num):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(x[i,:,:,0].astype(np.uint8))
    plt.axis('off')
# Out:
# (32, 28, 28, 1) (32, 28, 28, 1)
